# %%
import numpy as np
import numpy.random as random
import scipy as pd
import pandas as pd
from pandas import Series, DataFrame
import scipy.linalg as linalg
from scipy.optimize import minimize_scalar
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
# %matplotlib inline
# %precision 3
# Out:
# '%.3f'

# %%
dice_data = np.array([1, 2, 3, 4, 5, 6])

print(np.random.choice(dice_data, 1))
# Out:
# [1]

# %%
calc_steps = 1000

dice_rolls = np.random.choice(dice_data, calc_steps)
for i in range(1, 7):
    p = len(dice_rolls[dice_rolls == i]) / calc_steps
    print(i, p)
# Out:
# 1 0.17
# 2 0.161
# 3 0.154
# 4 0.174
# 5 0.165
# 6 0.176

# %%
n = 1000

coin_data = np.array([0, 1])
random.seed(0)
a = random.choice(coin_data, n)


for i in [0, 1]:
    print(i, len(a[a==i]) / n)
# Out:
# 0 0.496
# 1 0.504

# %%
0.99*0.001/(0.99*0.001 + 0.03*0.999)
# Out:
# 0.032

# %%
calc_steps = 1000

dice_roll = np.random.choice(dice_data, calc_steps)

prob_data = np.array([])
for i in range(1, 7):
    p = len(dice_roll[dice_roll==i]) / calc_steps
    prob_data = np.append(prob_data, len(dice_roll[dice_roll==i]) / calc_steps)


plt.bar(dice_data, prob_data)
plt.grid(True)

# %%
prob_be_data = np.array([])
coin_data = np.array([0, 0, 0, 0, 0, 1, 1, 1])
for i in np.unique(coin_data):
    p = len(coin_data[coin_data == i]) / len(coin_data)
    print(i, p)
    prob_be_data = np.append(prob_be_data, p)
# Out:
# 0 0.625
# 1 0.375

# %%
plt.bar([0, 1], prob_be_data, align='center')
plt.xticks([0, 1], ['head', 'tai'])
plt.grid(True)

# %%
np.random.seed(0)
x = np.random.binomial(30, 0.5, 1000)
plt.hist(x)
# Out:
# (array([  2.,  21.,  77., 198., 149., 267., 177.,  89.,  16.,   4.]),
#  array([ 6. ,  7.8,  9.6, 11.4, 13.2, 15. , 16.8, 18.6, 20.4, 22.2, 24. ]),
#  <BarContainer object of 10 artists>)

# %%
x = np.random.poisson(7, 1000)
plt.hist(x)
plt.grid(True)

# %%
x = np.random.normal(5, 10, 10000)
plt.hist(x)
plt.grid()

# %%
x = np.random.lognormal(30, 0.4, 1000)
plt.hist(x)
plt.grid()
